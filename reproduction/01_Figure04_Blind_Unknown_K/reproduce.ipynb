# %% [markdown]
# # Figure 4 — blind unknown-K comparison
#
# Checkpoint inference and released complete-response evaluation for TGCM, DANet, MossFormer2, DECOMPOSE, OpenAI, and Gemini.

# %%
from pathlib import Path
import sys

ROOT = next(
    candidate for candidate in (Path.cwd().resolve(), *Path.cwd().resolve().parents)
    if (candidate / "tgcm_review").is_dir()
)
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

FULL_REPRODUCTION = True
DEVICE = None
MAX_SEQUENCES = None if FULL_REPRODUCTION else 512
PROMPT_TEMPLATE = (ROOT / "paper_metadata" / "figure04_llm_prompt.txt").read_text(encoding="utf-8")
print("FULL PAPER RUN" if FULL_REPRODUCTION else "SMOKE TEST — NOT A PAPER RESULT")

# %%
from tgcm_review.paper_experiments import run_figure04

detail, summary = run_figure04(
    components=("tgcm", "danet", "mossformer", "decompose", "llm"),
    device=DEVICE,
    max_sequences=MAX_SEQUENCES,
)
summary
